# %% [markdown]
# <a href="https://colab.research.google.com/github/joao-dias-25/dataeng-spark/blob/main/spark_streaming/example_1_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Usecase 1
# - Defining a sample dataset
# - Splitting dataset in many CSVs and uploading them in the input folder in async mode
# - Use Spark streaming to read from input folder
# - Checking results from query in memory

# %% [markdown]
# # Setting up PySpark

# %%
# %pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
from pyspark.sql import SparkSession

#SparkSession.stop(spark)
spark = SparkSession.builder.master('local').appName('Test streaming').getOrCreate()
sc = spark.sparkContext

# %% [markdown]
# # Reading sample dataset

# %%
from pyspark import SparkFiles
from pyspark.sql.types import *
import uuid
from pyspark.sql.functions import udf
import pyspark.sql.functions as F
from pyspark.sql import DataFrame

def get_data(url: str, filename: str, schema) -> DataFrame:
  # read using SparkFiles
  spark.sparkContext.addFile(url)
  data = sc.textFile(SparkFiles.get(filename))

  # removing header
  header = data.first()
  data = data.filter(lambda line: line != header)

  df = spark.read.csv(data, header=True, schema=schema)
  return df

@udf
def generate_uuid():
  return str(uuid.uuid4())

schema = StructType([
StructField('Area Name',StringType(),True),
StructField('Area ID',StringType(),True),
StructField('Park Name',StringType(),True),
StructField('Park ID', StringType(), True),
StructField('Squirrel ID', StringType(), True),
StructField('Primary Fur Color', StringType(), True),
StructField('Highlights in Fur Color', StringType(), True),
StructField('Color Notes', StringType(), True),
StructField('Location', StringType(), True),
StructField('Above Ground (Height in Feet)', StringType(), True),
StructField('Specific Location', StringType(), True),
StructField('Activities', StringType(), True),
StructField('Interactions with Humans', StringType(), True),
StructField('Squirrel Latitude (DD.DDDDDD)', StringType(), True),
StructField('Squirrel Longitude (-DD.DDDDDD)', StringType(), True),
StructField('hash', StringType(), True)
])

df = get_data(url = "https://raw.githubusercontent.com/lucprosa/dataeng-basic-course/main/data/squirrel-data/squirrel-data.csv", filename = "squirrel-data.csv", schema = schema)
df = df.withColumn("hash", generate_uuid())

df = df.cache()
df.count()

df.show()
# Out:
# +---------------+-------+-------------------+-------+-----------+-----------------+-----------------------+-----------+------------+-----------------------------+-----------------+--------------------+------------------------+-----------------------------+-------------------------------+--------------------+
# |      Area Name|Area ID|          Park Name|Park ID|Squirrel ID|Primary Fur Color|Highlights in Fur Color|Color Notes|    Location|Above Ground (Height in Feet)|Specific Location|          Activities|Interactions with Humans|Squirrel Latitude (DD.DDDDDD)|Squirrel Longitude (-DD.DDDDDD)|                hash|
# +---------------+-------+-------------------+-------+-----------+-----------------+-----------------------+-----------+------------+-----------------------------+-----------------+--------------------+------------------------+-----------------------------+-------------------------------+--------------------+
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-02|             Gray|                  White|       NULL|Ground Plane|                         NULL|             NULL|            Foraging|             Indifferent|                 Looks skinny|                      40.859436|f81f0c44-2895-4ec...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-03|             Gray|                  White|       NULL|Ground Plane|                         NULL|             NULL|Eating, Digging s...|             Indifferent|                         NULL|                      40.859416|e3872950-a21e-43c...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-04|             Gray|                  White|       NULL|Ground Plane|                         NULL|             NULL|             Running|             Indifferent|                         NULL|                      40.859418|5832cb07-710c-429...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-05|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|     Running, Eating|             Indifferent|                She left food|                      40.859493|6f9e527f-803d-40e...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-06|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|            Climbing|             Indifferent|                         NULL|                      40.860825|b08d9ae3-0300-4fa...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-07|             Gray|                  White|       NULL|Ground Plane|                         NULL|             NULL|            Foraging|             Indifferent|                         NULL|                      40.860225|539d92ba-a6ca-4de...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-08|            Black|                   Gray|       NULL|Above Ground|                           10|             NULL|            Climbing|               Runs From|                         NULL|                      40.859965|4032c01a-41ee-41a...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-09|             Gray|                  White|       NULL|Ground Plane|                         NULL|             NULL|            Foraging|             Indifferent|                         NULL|                      40.859892|34c00f16-f260-45d...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-10|             Gray|                  White|       NULL|Ground Plane|                         NULL|             NULL|     Eating, Digging|             Indifferent|                         NULL|                      40.859636|0234dfdf-e4c7-46d...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-11|             Gray|                  Black|       NULL|Ground Plane|                         NULL|             NULL|     Eating, Digging|             Indifferent|         was intimidated b...|                      40.859576|68191ec8-ecb8-4e9...|
# |UPPER MANHATTAN|      A|    Fort Tryon Park|     01|    A-01-12|             Gray|                  White|       NULL|Ground Plane|                         NULL|             NULL|             Running|               Runs From|                         NULL|                      40.859989|a094acf3-ff38-48b...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-01|             Gray|                   Gray|       NULL|Ground Plane|                         NULL|             NULL|             Running|             Indifferent|                         NULL|                      40.845749|3402f563-30f3-415...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-02|             Gray|               Cinnamon|       NULL|Above Ground|                            2|             NULL|            Foraging|             Indifferent|                         NULL|                      40.845875|444f4c19-5980-472...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-03|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|            Foraging|                    NULL|                         NULL|                      40.845875|88d25b5f-c627-4f7...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-04|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|             Running|             Indifferent|                         NULL|                      40.846088|9499298a-c90c-45b...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-05|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|             Running|               Runs From|                         NULL|                      40.846088|43a4f582-481c-494...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-06|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|            Foraging|             Indifferent|                         NULL|                      40.846088|29f1b5cd-4ca9-4e9...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-07|             Gray|                   Gray|       NULL|Ground Plane|                         NULL|             NULL|                NULL|               Runs From|                         NULL|                      40.846222|b5f3a7dd-c439-418...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-08|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|Foraging, Nesting...|             Indifferent|                         NULL|                      40.846222|27a39d84-98fb-4d0...|
# |UPPER MANHATTAN|      A|J. Hood Wright Park|     02|    A-02-09|             Gray|               Cinnamon|       NULL|Ground Plane|                         NULL|             NULL|             Chasing|             Indifferent|                         NULL|                      40.846197|55109c05-30d7-408...|
# +---------------+-------+-------------------+-------+-----------+-----------------+-----------------------+-----------+------------+-----------------------------+-----------------+--------------------+------------------------+-----------------------------+-------------------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # Removing folders

# %%
# !rm -rf /content/input/
# !rm -rf /content/output/
# !rm -rf /content/checkpoint/

# %% [markdown]
# # Splitting dataset in many CSVs and uploading them in async mode
#
# - split csv files in many small files
# - sleep some seconds between each process
# - write small file into input folder

# %%
from pyspark.sql import DataFrame
import time
import asyncio

# Function to split csv into many files (assync)
async def splitDf(df: DataFrame, weight: float, files: int):
  weights = [weight for i in range(files)]
  dfs = df.randomSplit(weights)
  return dfs

# Function to write data as csv (assync)
async def writeFile(dfs: list[DataFrame], path: str, seconds_per_file: int):
  for i in range(len(dfs)):
    df = dfs[i]
    #print(f"Writing file {path}file_{i}.csv with {df.count()} lines")
    df.write.mode("append").format("csv").save(path)
    await asyncio.sleep(seconds_per_file)

async def main(df):
  files = 20
  seconds_per_file = 10
  dfs = await splitDf(df, 1.0, files)
  asyncio.create_task(writeFile(dfs, "/content/input/", seconds_per_file))

# %% [markdown]
# # Start producer

# %%
await main(df)

# %% [markdown]
# # Defining streaming functions
#
# - streaming_1
#   - read streaming data from csv
#   - write streaming data using MEMORY
#   - query "my_query" to check results
#
# - streaming_2
#   - read streaming data from csv
#   - write streaming data as PARQUET
#       - define checkpoint
#       - trigger time of 5 seconds
#       - mode append

# %%
from pyspark.sql.streaming import StreamingQuery

def streaming_1(queryName: str) -> StreamingQuery:

  # Start read of file stream (csv) from input folder
  stream1 = spark.readStream.format('csv').schema(schema).option('header', False).load('/content/input/')

  # Check if dataframe is streaming
  print(stream1.isStreaming)

  # Start write as streaming into memory
  query = (stream1.writeStream
  .format('memory')
  .queryName(queryName)
  .trigger(processingTime='5 seconds')
  .outputMode('append')
  .start()
  )
  return query

def streaming_2() -> StreamingQuery:

  # Start read of file stream (csv) from input folder
  stream1 = spark.readStream.format('csv').schema(schema).option('header', False).load('/content/input/')

  # Check if dataframe is streaming
  print(stream1.isStreaming)

  # Start write as streaming into memory
  query = (stream1.writeStream
  .format('parquet')
  .option('path', '/content/output')
  .option('checkpointLocation', '/content/checkpoint')
  .trigger(processingTime='5 seconds')
  .outputMode('append')
  .start()
  )
  return query

# %% [markdown]
# # Start streaming_1 (memory)

# %%
query = streaming_1("qry1")
# Out:
# True

# %%
# querying data in memory
spark.sql("select count(1) from qry1").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |      21|
# +--------+

# %%
# checking results
df.count() == spark.sql("select * from qry1").count()
# Out:
# False

# %% [markdown]
# # Stop writeStreaming

# %%
query.stop()

# %% [markdown]
# # Start streaming_2 (parquet)

# %%
query = streaming_2()
# Out:
# True

# %%
query.stop()

# %% [markdown]
# # Checking output

# %%
df.count()
# Out:
# 432

# %%
input = spark.read.format("csv").load("/content/input/*")
output = spark.read.format("parquet").schema(schema).load("/content/output/*")

print(f"input - {input.count()}")
print(f"output - {output.count()}")
# Out:
# input - 350
# output - 350

# %%
query.stop()

# %%
# Counting csv files in INPUT folder
# !ls -l /content/input | grep .csv | wc -l
# Out:
# 17

# %%
# Counting csv files in OUTPUT folder
# !ls -l /content/output | grep .parquet | wc -l
# Out:
# 7

# %%
# check streaming query attributes
query.lastProgress
query.lastProgress['numInputRows']
query.recentProgress
query.id
query.name
query.status
# Out:
# {'message': 'Stopped', 'isDataAvailable': False, 'isTriggerActive': False}

# %%
# Out:
# [{'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:31:25.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:31:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:31:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:32:10.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:32:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 6, 'triggerExecution': 6},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:32:35.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:32:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:33:00.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:33:10.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:33:20.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:33:35.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:33:45.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:33:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:34:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:34:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:34:30.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:34:45.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:34:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:35:10.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:35:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:35:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:35:45.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:35:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:36:05.003Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:36:20.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:36:30.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 10, 'triggerExecution': 10},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:36:45.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:36:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:37:10.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:37:25.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:37:35.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:37:45.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:37:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:38:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:38:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:38:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:38:45.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:39:00.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:39:10.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:39:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:39:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:39:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:39:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:40:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:40:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:40:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:40:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:40:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 18, 'triggerExecution': 18},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:41:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:41:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:41:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:41:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:41:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:42:00.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:42:15.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:42:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:42:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:42:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:43:05.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:43:15.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:43:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:43:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:43:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:44:05.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:44:15.003Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:44:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:44:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:44:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:45:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:45:15.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:45:30.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
# ...
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:46:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:46:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:47:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:47:15.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:47:25.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:47:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:47:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:48:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:48:20.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:48:35.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:48:45.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:48:55.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:49:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:49:15.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:49:25.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:49:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:49:50.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:50:00.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:50:10.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:50:25.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:50:40.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:50:55.001Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}},
#  {'id': 'c3f0969a-698e-4cce-8751-d1b85e373cb2',
#   'runId': 'b91b4c62-933c-4863-97ff-11a3d76f2ddd',
#   'name': None,
#   'timestamp': '2024-11-20T21:51:05.000Z',
#   'batchId': 19,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'FileStreamSource[file:/content/input]',
#     'startOffset': {'logOffset': 18},
#     'endOffset': {'logOffset': 18},
#     'latestOffset': None,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'FileSink[/content/output]', 'numOutputRows': -1}}]

# %%
# checking input schema
input.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#  |-- _c8: string (nullable = true)
#  |-- _c9: string (nullable = true)
#  |-- _c10: string (nullable = true)
#  |-- _c11: string (nullable = true)
#  |-- _c12: string (nullable = true)
#  |-- _c13: string (nullable = true)
#  |-- _c14: string (nullable = true)
#  |-- _c15: string (nullable = true)

# %%
# checking output schema
output.printSchema()
# Out:
# root
#  |-- Area Name: string (nullable = true)
#  |-- Area ID: string (nullable = true)
#  |-- Park Name: string (nullable = true)
#  |-- Park ID: string (nullable = true)
#  |-- Squirrel ID: string (nullable = true)
#  |-- Primary Fur Color: string (nullable = true)
#  |-- Highlights in Fur Color: string (nullable = true)
#  |-- Color Notes: string (nullable = true)
#  |-- Location: string (nullable = true)
#  |-- Above Ground (Height in Feet): string (nullable = true)
#  |-- Specific Location: string (nullable = true)
#  |-- Activities: string (nullable = true)
#  |-- Interactions with Humans: string (nullable = true)
#  |-- Squirrel Latitude (DD.DDDDDD): string (nullable = true)
#  |-- Squirrel Longitude (-DD.DDDDDD): string (nullable = true)
#  |-- hash: string (nullable = true)
