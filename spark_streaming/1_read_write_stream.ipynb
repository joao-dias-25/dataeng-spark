# %% [markdown]
# <a href="https://colab.research.google.com/github/joao-dias-25/dataeng-spark/blob/main/spark_streaming/1_read_write_stream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read & Write Stream
# - readStream()
# - writeStream()
# - Streaming Dataframe

# %% [markdown]
# # Setting up PySpark

# %%
# %pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.master('local').appName('Test streaming').getOrCreate()

# %% [markdown]
# # readStream with format "rate"
# - readStream
# - format("rate")

# %%
import pyspark.sql.functions as F

# read stream
stream = spark.readStream.format("rate").load()

# %%
type(stream)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
# checking if it's streaming dataframe
stream.isStreaming
# Out:
# True

# %%
# should be false
data = [("c1", "v1"), ("c2", "v2")]
columns = ["col1", "col2"]
df = spark.createDataFrame(data, columns)
df.isStreaming
# Out:
# False

# %%
# apply normal dataframe operations
stream.printSchema()
# Out:
# root
#  |-- timestamp: timestamp (nullable = true)
#  |-- value: long (nullable = true)

# %%
# Queries with streaming sources must be executed with writeStream.start();
# stream.show()
stream.count()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-8-2c876bdc4c4f> in <cell line: 3>()
#       1 # Queries with streaming sources must be executed with writeStream.start();
#       2 # stream.show()
# ----> 3 stream.count()
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py in count(self)
#    1238         3
#    1239         """
# -> 1240         return int(self._jdf.count())
#    1241
#    1242     def collect(self) -> List[Row]:
#
# /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1320
#    1321         answer = self.gateway_client.send_command(command)
# -> 1322         return_value = get_return_value(
#    1323             answer, self.gateway_client, self.target_id, self.name)
#    1324
#
# /usr/local/lib/python3.10/dist-packages/pyspark/errors/exceptions/captured.py in deco(*a, **kw)
#     183                 # Hide where the exception came from that shows a non-Pythonic
#     184                 # JVM exception message.
# --> 185                 raise converted from None
#     186             else:
#     187                 raise
#
# AnalysisException: Queries with streaming sources must be executed with writeStream.start();
# rate

# %% [markdown]
# # Transfor streaming dataframe

# %%
transformed = stream.withColumn("value2", F.col("value") * 2)

# %%
transformed.isStreaming
# Out:
# True

# %% [markdown]
# # write streaming dataframe - format memory
# - writeStream
# - format("memory")
# - queryName
# - outputMode
# - start

# %%
query = (transformed.writeStream
  .format('memory')
  .queryName('rate_report')
  .outputMode('append')
  .start()
)

# %% [markdown]
# # Checking result table

# %%
# StreamingQuery
type(query)
# Out:
# pyspark.sql.streaming.query.StreamingQuery

# %%
print(spark.table("rate_report").count())
spark.table("rate_report").orderBy(F.desc('timestamp')).show(20, False)

# one line per second
# Out:
# 349
# +-----------------------+-----+------+
# |timestamp              |value|value2|
# +-----------------------+-----+------+
# |2024-11-23 14:06:52.261|348  |696   |
# |2024-11-23 14:06:51.261|347  |694   |
# |2024-11-23 14:06:50.261|346  |692   |
# |2024-11-23 14:06:49.261|345  |690   |
# |2024-11-23 14:06:48.261|344  |688   |
# |2024-11-23 14:06:47.261|343  |686   |
# |2024-11-23 14:06:46.261|342  |684   |
# |2024-11-23 14:06:45.261|341  |682   |
# |2024-11-23 14:06:44.261|340  |680   |
# |2024-11-23 14:06:43.261|339  |678   |
# |2024-11-23 14:06:42.261|338  |676   |
# |2024-11-23 14:06:41.261|337  |674   |
# |2024-11-23 14:06:40.261|336  |672   |
# |2024-11-23 14:06:39.261|335  |670   |
# |2024-11-23 14:06:38.261|334  |668   |
# |2024-11-23 14:06:37.261|333  |666   |
# |2024-11-23 14:06:36.261|332  |664   |
# |2024-11-23 14:06:35.261|331  |662   |
# |2024-11-23 14:06:34.261|330  |660   |
# |2024-11-23 14:06:33.261|329  |658   |
# +-----------------------+-----+------+
# only showing top 20 rows

# %%
query.status
# Out:
# {'message': 'Waiting for data to arrive',
#  'isDataAvailable': False,
#  'isTriggerActive': False}

# %%
query.isActive
# Out:
# True

# %%
query.recentProgress
# Out:
# [{'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:12.265Z',
#   'batchId': 307,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 11.627906976744187,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 26,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 86,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 307,
#     'endOffset': 308,
#     'latestOffset': 308,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 11.627906976744187}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:13.271Z',
#   'batchId': 308,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 11.363636363636365,
#   'durationMs': {'addBatch': 27,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 88,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 308,
#     'endOffset': 309,
#     'latestOffset': 309,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 11.363636363636365}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:14.269Z',
#   'batchId': 309,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 5.813953488372094,
#   'durationMs': {'addBatch': 53,
#    'commitOffsets': 85,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 172,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 309,
#     'endOffset': 310,
#     'latestOffset': 310,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 5.813953488372094}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:15.267Z',
#   'batchId': 310,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.235955056179776,
#   'durationMs': {'addBatch': 27,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 89,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 310,
#     'endOffset': 311,
#     'latestOffset': 311,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.235955056179776}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:16.266Z',
#   'batchId': 311,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 8.474576271186441,
#   'durationMs': {'addBatch': 42,
#    'commitOffsets': 42,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 118,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 311,
#     'endOffset': 312,
#     'latestOffset': 312,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 8.474576271186441}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:17.270Z',
#   'batchId': 312,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 8.130081300813009,
#   'durationMs': {'addBatch': 34,
#    'commitOffsets': 41,
#    'getBatch': 1,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 123,
#    'walCommit': 41},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 312,
#     'endOffset': 313,
#     'latestOffset': 313,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 8.130081300813009}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:18.270Z',
#   'batchId': 313,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.235955056179776,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 89,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 313,
#     'endOffset': 314,
#     'latestOffset': 314,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.235955056179776}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:19.268Z',
#   'batchId': 314,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.8125,
#   'durationMs': {'addBatch': 47,
#    'commitOffsets': 48,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 128,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 314,
#     'endOffset': 315,
#     'latestOffset': 315,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.8125}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:20.275Z',
#   'batchId': 315,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 66.66666666666667,
#   'processedRowsPerSecond': 8.0,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 32,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 125,
#    'walCommit': 56},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 315,
#     'endOffset': 316,
#     'latestOffset': 316,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 66.66666666666667,
#     'processedRowsPerSecond': 8.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:21.270Z',
#   'batchId': 316,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.097560975609756,
#   'durationMs': {'addBatch': 60,
#    'commitOffsets': 46,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 164,
#    'walCommit': 53},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 316,
#     'endOffset': 317,
#     'latestOffset': 317,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.097560975609756}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:22.266Z',
#   'batchId': 317,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 9.523809523809524,
#   'durationMs': {'addBatch': 38,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 105,
#    'walCommit': 33},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 317,
#     'endOffset': 318,
#     'latestOffset': 318,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 9.523809523809524}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:23.262Z',
#   'batchId': 318,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.751937984496124,
#   'durationMs': {'addBatch': 29,
#    'commitOffsets': 33,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 129,
#    'walCommit': 62},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 318,
#     'endOffset': 319,
#     'latestOffset': 319,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.751937984496124}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:24.269Z',
#   'batchId': 319,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.751937984496124,
#   'durationMs': {'addBatch': 47,
#    'commitOffsets': 45,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 129,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 319,
#     'endOffset': 320,
#     'latestOffset': 320,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.751937984496124}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:25.263Z',
#   'batchId': 320,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.1010101010101,
#   'durationMs': {'addBatch': 31,
#    'commitOffsets': 30,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 99,
#    'walCommit': 33},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 320,
#     'endOffset': 321,
#     'latestOffset': 321,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.1010101010101}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:26.262Z',
#   'batchId': 321,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 10.526315789473685,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 30,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 95,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 321,
#     'endOffset': 322,
#     'latestOffset': 322,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 10.526315789473685}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:27.262Z',
#   'batchId': 322,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 6.172839506172839,
#   'durationMs': {'addBatch': 53,
#    'commitOffsets': 76,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 162,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 322,
#     'endOffset': 323,
#     'latestOffset': 323,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 6.172839506172839}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:28.261Z',
#   'batchId': 323,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 5.952380952380952,
#   'durationMs': {'addBatch': 75,
#    'commitOffsets': 42,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 168,
#    'walCommit': 43},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 323,
#     'endOffset': 324,
#     'latestOffset': 324,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 5.952380952380952}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:29.263Z',
#   'batchId': 324,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.802721088435375,
#   'durationMs': {'addBatch': 49,
#    'commitOffsets': 46,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 147,
#    'walCommit': 44},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 324,
#     'endOffset': 325,
#     'latestOffset': 325,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.802721088435375}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:30.269Z',
#   'batchId': 325,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 10.526315789473685,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 31,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 95,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 325,
#     'endOffset': 326,
#     'latestOffset': 326,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 10.526315789473685}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:31.266Z',
#   'batchId': 326,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.345794392523365,
#   'durationMs': {'addBatch': 33,
#    'commitOffsets': 39,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 107,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 326,
#     'endOffset': 327,
#     'latestOffset': 327,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.345794392523365}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:32.262Z',
#   'batchId': 327,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.092198581560284,
#   'durationMs': {'addBatch': 50,
#    'commitOffsets': 57,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 141,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 327,
#     'endOffset': 328,
#     'latestOffset': 328,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.092198581560284}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:33.267Z',
#   'batchId': 328,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.0,
#   'durationMs': {'addBatch': 32,
#    'commitOffsets': 34,
#    'getBatch': 1,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 100,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 328,
#     'endOffset': 329,
#     'latestOffset': 329,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:34.266Z',
#   'batchId': 329,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.204081632653061,
#   'durationMs': {'addBatch': 29,
#    'commitOffsets': 35,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 98,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 329,
#     'endOffset': 330,
#     'latestOffset': 330,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.204081632653061}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:35.265Z',
#   'batchId': 330,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.989010989010989,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 30,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 91,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 330,
#     'endOffset': 331,
#     'latestOffset': 331,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.989010989010989}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:36.266Z',
#   'batchId': 331,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 8.403361344537815,
#   'durationMs': {'addBatch': 39,
#    'commitOffsets': 46,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 119,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 331,
#     'endOffset': 332,
#     'latestOffset': 332,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 8.403361344537815}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:37.264Z',
#   'batchId': 332,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.042253521126761,
#   'durationMs': {'addBatch': 56,
#    'commitOffsets': 53,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 142,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 332,
#     'endOffset': 333,
#     'latestOffset': 333,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.042253521126761}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:38.261Z',
#   'batchId': 333,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.235955056179776,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 30,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 89,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 333,
#     'endOffset': 334,
#     'latestOffset': 334,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.235955056179776}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:39.270Z',
#   'batchId': 334,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 11.363636363636365,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 88,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 334,
#     'endOffset': 335,
#     'latestOffset': 335,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 11.363636363636365}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:40.267Z',
#   'batchId': 335,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.172839506172839,
#   'durationMs': {'addBatch': 58,
#    'commitOffsets': 45,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 8,
#    'triggerExecution': 162,
#    'walCommit': 51},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 335,
#     'endOffset': 336,
#     'latestOffset': 336,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.172839506172839}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:41.263Z',
#   'batchId': 336,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.0606060606060606,
#   'durationMs': {'addBatch': 63,
#    'commitOffsets': 50,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 8,
#    'triggerExecution': 165,
#    'walCommit': 42},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 336,
#     'endOffset': 337,
#     'latestOffset': 337,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.0606060606060606}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:42.264Z',
#   'batchId': 337,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.462686567164178,
#   'durationMs': {'addBatch': 57,
#    'commitOffsets': 44,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 134,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 337,
#     'endOffset': 338,
#     'latestOffset': 338,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.462686567164178}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:43.270Z',
#   'batchId': 338,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.904761904761903,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 84,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 338,
#     'endOffset': 339,
#     'latestOffset': 339,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.904761904761903}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:44.262Z',
#   'batchId': 339,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.235955056179776,
#   'durationMs': {'addBatch': 29,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 89,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 339,
#     'endOffset': 340,
#     'latestOffset': 340,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.235955056179776}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:45.271Z',
#   'batchId': 340,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 9.803921568627452,
#   'durationMs': {'addBatch': 29,
#    'commitOffsets': 41,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 102,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 340,
#     'endOffset': 341,
#     'latestOffset': 341,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 9.803921568627452}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:46.262Z',
#   'batchId': 341,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.19672131147541,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 61,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 122,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 341,
#     'endOffset': 342,
#     'latestOffset': 342,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.19672131147541}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:47.262Z',
#   'batchId': 342,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.2992700729927,
#   'durationMs': {'addBatch': 48,
#    'commitOffsets': 55,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 137,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 342,
#     'endOffset': 343,
#     'latestOffset': 343,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.2992700729927}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:48.264Z',
#   'batchId': 343,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 3.1645569620253164,
#   'durationMs': {'addBatch': 84,
#    'commitOffsets': 183,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 316,
#    'walCommit': 41},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 343,
#     'endOffset': 344,
#     'latestOffset': 344,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 3.1645569620253164}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:49.263Z',
#   'batchId': 344,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.989010989010989,
#   'durationMs': {'addBatch': 29,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 91,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 344,
#     'endOffset': 345,
#     'latestOffset': 345,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.989010989010989}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:50.266Z',
#   'batchId': 345,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.989010989010989,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 91,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 345,
#     'endOffset': 346,
#     'latestOffset': 346,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.989010989010989}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:51.266Z',
#   'batchId': 346,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 10.869565217391305,
#   'durationMs': {'addBatch': 31,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 92,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 346,
#     'endOffset': 347,
#     'latestOffset': 347,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 10.869565217391305}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:52.268Z',
#   'batchId': 347,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 6.329113924050633,
#   'durationMs': {'addBatch': 60,
#    'commitOffsets': 48,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 158,
#    'walCommit': 44},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 347,
#     'endOffset': 348,
#     'latestOffset': 348,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 6.329113924050633}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:53.270Z',
#   'batchId': 348,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.410256410256411,
#   'durationMs': {'addBatch': 59,
#    'commitOffsets': 49,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 156,
#    'walCommit': 41},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 348,
#     'endOffset': 349,
#     'latestOffset': 349,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.410256410256411}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:54.268Z',
#   'batchId': 349,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.708737864077671,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 103,
#    'walCommit': 41},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 349,
#     'endOffset': 350,
#     'latestOffset': 350,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.708737864077671}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:55.271Z',
#   'batchId': 350,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 8.403361344537815,
#   'durationMs': {'addBatch': 39,
#    'commitOffsets': 47,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 119,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 350,
#     'endOffset': 351,
#     'latestOffset': 351,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 8.403361344537815}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:56.269Z',
#   'batchId': 351,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 5.555555555555555,
#   'durationMs': {'addBatch': 64,
#    'commitOffsets': 78,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 180,
#    'walCommit': 33},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 351,
#     'endOffset': 352,
#     'latestOffset': 352,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 5.555555555555555}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:57.263Z',
#   'batchId': 352,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.235955056179776,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 89,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 352,
#     'endOffset': 353,
#     'latestOffset': 353,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.235955056179776}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:58.263Z',
#   'batchId': 353,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 9.708737864077671,
#   'durationMs': {'addBatch': 35,
#    'commitOffsets': 34,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 103,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 353,
#     'endOffset': 354,
#     'latestOffset': 354,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 9.708737864077671}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:06:59.265Z',
#   'batchId': 354,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.309278350515463,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 38,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 97,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 354,
#     'endOffset': 355,
#     'latestOffset': 355,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.309278350515463}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:00.262Z',
#   'batchId': 355,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.235955056179776,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 89,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 355,
#     'endOffset': 356,
#     'latestOffset': 356,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.235955056179776}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:01.261Z',
#   'batchId': 356,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 7.936507936507937,
#   'durationMs': {'addBatch': 47,
#    'commitOffsets': 45,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 126,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 356,
#     'endOffset': 357,
#     'latestOffset': 357,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 7.936507936507937}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:02.265Z',
#   'batchId': 357,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.462686567164178,
#   'durationMs': {'addBatch': 42,
#    'commitOffsets': 43,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 134,
#    'walCommit': 42},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 357,
#     'endOffset': 358,
#     'latestOffset': 358,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.462686567164178}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:03.268Z',
#   'batchId': 358,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.204081632653061,
#   'durationMs': {'addBatch': 33,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 98,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 358,
#     'endOffset': 359,
#     'latestOffset': 359,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.204081632653061}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:04.265Z',
#   'batchId': 359,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.666666666666667,
#   'durationMs': {'addBatch': 48,
#    'commitOffsets': 51,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 150,
#    'walCommit': 44},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 359,
#     'endOffset': 360,
#     'latestOffset': 360,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.666666666666667}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:05.261Z',
#   'batchId': 360,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.2992700729927,
#   'durationMs': {'addBatch': 51,
#    'commitOffsets': 40,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 137,
#    'walCommit': 40},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 360,
#     'endOffset': 361,
#     'latestOffset': 361,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.2992700729927}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:06.265Z',
#   'batchId': 361,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 3.048780487804878,
#   'durationMs': {'addBatch': 62,
#    'commitOffsets': 223,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 328,
#    'walCommit': 36},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 361,
#     'endOffset': 362,
#     'latestOffset': 362,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 3.048780487804878}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:07.265Z',
#   'batchId': 362,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.526315789473685,
#   'durationMs': {'addBatch': 34,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 95,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 362,
#     'endOffset': 363,
#     'latestOffset': 363,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.526315789473685}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:08.270Z',
#   'batchId': 363,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 10.638297872340425,
#   'durationMs': {'addBatch': 32,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 94,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 363,
#     'endOffset': 364,
#     'latestOffset': 364,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 10.638297872340425}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:09.263Z',
#   'batchId': 364,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.526315789473685,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 34,
#    'getBatch': 1,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 95,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 364,
#     'endOffset': 365,
#     'latestOffset': 365,
#     'numInputRows': 1,
# ...
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.944444444444445}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:32.265Z',
#   'batchId': 387,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 11.627906976744187,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 86,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 387,
#     'endOffset': 388,
#     'latestOffset': 388,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 11.627906976744187}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:33.262Z',
#   'batchId': 388,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 10.869565217391305,
#   'durationMs': {'addBatch': 29,
#    'commitOffsets': 30,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 92,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 388,
#     'endOffset': 389,
#     'latestOffset': 389,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 10.869565217391305}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:34.264Z',
#   'batchId': 389,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.627906976744187,
#   'durationMs': {'addBatch': 24,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 86,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 389,
#     'endOffset': 390,
#     'latestOffset': 390,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.627906976744187}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:35.269Z',
#   'batchId': 390,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.25925925925926,
#   'durationMs': {'addBatch': 31,
#    'commitOffsets': 45,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 108,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 390,
#     'endOffset': 391,
#     'latestOffset': 391,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.25925925925926}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:36.266Z',
#   'batchId': 391,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 8.403361344537815,
#   'durationMs': {'addBatch': 45,
#    'commitOffsets': 42,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 119,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 391,
#     'endOffset': 392,
#     'latestOffset': 392,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 8.403361344537815}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:37.264Z',
#   'batchId': 392,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.523809523809524,
#   'durationMs': {'addBatch': 33,
#    'commitOffsets': 38,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 105,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 392,
#     'endOffset': 393,
#     'latestOffset': 393,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.523809523809524}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:38.269Z',
#   'batchId': 393,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 9.900990099009901,
#   'durationMs': {'addBatch': 29,
#    'commitOffsets': 39,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 101,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 393,
#     'endOffset': 394,
#     'latestOffset': 394,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 9.900990099009901}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:39.269Z',
#   'batchId': 394,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.803921568627452,
#   'durationMs': {'addBatch': 29,
#    'commitOffsets': 40,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 102,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 394,
#     'endOffset': 395,
#     'latestOffset': 395,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.803921568627452}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:40.269Z',
#   'batchId': 395,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 8.19672131147541,
#   'durationMs': {'addBatch': 32,
#    'commitOffsets': 43,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 122,
#    'walCommit': 41},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 395,
#     'endOffset': 396,
#     'latestOffset': 396,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 8.19672131147541}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:41.267Z',
#   'batchId': 396,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 4.166666666666667,
#   'durationMs': {'addBatch': 91,
#    'commitOffsets': 100,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 8,
#    'triggerExecution': 240,
#    'walCommit': 41},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 396,
#     'endOffset': 397,
#     'latestOffset': 397,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 4.166666666666667}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:42.261Z',
#   'batchId': 397,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.195121951219512,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 82,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 397,
#     'endOffset': 398,
#     'latestOffset': 398,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.195121951219512}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:43.263Z',
#   'batchId': 398,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.416666666666666,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 10,
#    'triggerExecution': 96,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 398,
#     'endOffset': 399,
#     'latestOffset': 399,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.416666666666666}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:44.268Z',
#   'batchId': 399,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.526315789473685,
#   'durationMs': {'addBatch': 32,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 95,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 399,
#     'endOffset': 400,
#     'latestOffset': 400,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.526315789473685}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:45.262Z',
#   'batchId': 400,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.989010989010989,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 32,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 91,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 400,
#     'endOffset': 401,
#     'latestOffset': 401,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.989010989010989}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:46.262Z',
#   'batchId': 401,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 4.651162790697675,
#   'durationMs': {'addBatch': 55,
#    'commitOffsets': 126,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 215,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 401,
#     'endOffset': 402,
#     'latestOffset': 402,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 4.651162790697675}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:47.264Z',
#   'batchId': 402,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.00900900900901,
#   'durationMs': {'addBatch': 32,
#    'commitOffsets': 48,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 111,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 402,
#     'endOffset': 403,
#     'latestOffset': 403,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.00900900900901}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:48.263Z',
#   'batchId': 403,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.49425287356322,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 87,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 403,
#     'endOffset': 404,
#     'latestOffset': 404,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.49425287356322}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:49.270Z',
#   'batchId': 404,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 9.615384615384615,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 41,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 104,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 404,
#     'endOffset': 405,
#     'latestOffset': 405,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 9.615384615384615}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': 'e8bec84d-c1fd-47fd-9434-861fea6224e1',
#   'runId': '7a425ea8-e17d-49f2-be4d-e3fc87cf49ff',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:07:50.265Z',
#   'batchId': 405,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 11.904761904761903,
#   'durationMs': {'addBatch': 24,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 84,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 405,
#     'endOffset': 406,
#     'latestOffset': 406,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 11.904761904761903}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}}]

# %%
query.lastProgress['batchId']
# Out:
# 480

# %% [markdown]
# # Stop streaming

# %%
query.stop()

# %%
spark.sql("select * from rate_report").show()
# Out:
# +--------------------+-----+------+
# |           timestamp|value|value2|
# +--------------------+-----+------+
# |2024-11-23 14:01:...|    0|     0|
# |2024-11-23 14:01:...|    1|     2|
# |2024-11-23 14:01:...|    2|     4|
# |2024-11-23 14:01:...|    3|     6|
# |2024-11-23 14:01:...|    4|     8|
# |2024-11-23 14:01:...|    5|    10|
# |2024-11-23 14:01:...|    6|    12|
# |2024-11-23 14:01:...|    7|    14|
# |2024-11-23 14:01:...|    8|    16|
# |2024-11-23 14:01:...|    9|    18|
# |2024-11-23 14:01:...|   10|    20|
# |2024-11-23 14:01:...|   11|    22|
# |2024-11-23 14:01:...|   12|    24|
# |2024-11-23 14:01:...|   13|    26|
# |2024-11-23 14:01:...|   14|    28|
# |2024-11-23 14:01:...|   15|    30|
# |2024-11-23 14:01:...|   16|    32|
# |2024-11-23 14:01:...|   17|    34|
# |2024-11-23 14:01:...|   18|    36|
# |2024-11-23 14:01:...|   19|    38|
# +--------------------+-----+------+
# only showing top 20 rows

# %%
# awaitTermination

# %% [markdown]
# # Increase rows per second (rate)

# %%
# read stream
stream = spark.readStream.format("rate").option("rowsPerSecond", 20).load()

transformed = stream.withColumn("value2", F.col("value") * 2)

query = (transformed.writeStream
  .format('memory')
  .queryName('rate_report_2')
  .outputMode('append')
  .start()
)

# %%
print(spark.table("rate_report_2").count())
spark.table("rate_report_2").show(100, False)
# Out:
# 860
# +-----------------------+-----+------+
# |timestamp              |value|value2|
# +-----------------------+-----+------+
# |2024-11-23 14:18:10.743|0    |0     |
# |2024-11-23 14:18:10.793|1    |2     |
# |2024-11-23 14:18:10.843|2    |4     |
# |2024-11-23 14:18:10.893|3    |6     |
# |2024-11-23 14:18:10.943|4    |8     |
# |2024-11-23 14:18:10.993|5    |10    |
# |2024-11-23 14:18:11.043|6    |12    |
# |2024-11-23 14:18:11.093|7    |14    |
# |2024-11-23 14:18:11.143|8    |16    |
# |2024-11-23 14:18:11.193|9    |18    |
# |2024-11-23 14:18:11.243|10   |20    |
# |2024-11-23 14:18:11.293|11   |22    |
# |2024-11-23 14:18:11.343|12   |24    |
# |2024-11-23 14:18:11.393|13   |26    |
# |2024-11-23 14:18:11.443|14   |28    |
# |2024-11-23 14:18:11.493|15   |30    |
# |2024-11-23 14:18:11.543|16   |32    |
# |2024-11-23 14:18:11.593|17   |34    |
# |2024-11-23 14:18:11.643|18   |36    |
# |2024-11-23 14:18:11.693|19   |38    |
# |2024-11-23 14:18:11.743|20   |40    |
# |2024-11-23 14:18:11.793|21   |42    |
# |2024-11-23 14:18:11.843|22   |44    |
# |2024-11-23 14:18:11.893|23   |46    |
# |2024-11-23 14:18:11.943|24   |48    |
# |2024-11-23 14:18:11.993|25   |50    |
# |2024-11-23 14:18:12.043|26   |52    |
# |2024-11-23 14:18:12.093|27   |54    |
# |2024-11-23 14:18:12.143|28   |56    |
# |2024-11-23 14:18:12.193|29   |58    |
# |2024-11-23 14:18:12.243|30   |60    |
# |2024-11-23 14:18:12.293|31   |62    |
# |2024-11-23 14:18:12.343|32   |64    |
# |2024-11-23 14:18:12.393|33   |66    |
# |2024-11-23 14:18:12.443|34   |68    |
# |2024-11-23 14:18:12.493|35   |70    |
# |2024-11-23 14:18:12.543|36   |72    |
# |2024-11-23 14:18:12.593|37   |74    |
# |2024-11-23 14:18:12.643|38   |76    |
# |2024-11-23 14:18:12.693|39   |78    |
# |2024-11-23 14:18:12.743|40   |80    |
# |2024-11-23 14:18:12.793|41   |82    |
# |2024-11-23 14:18:12.843|42   |84    |
# |2024-11-23 14:18:12.893|43   |86    |
# |2024-11-23 14:18:12.943|44   |88    |
